# %% [markdown]
# # Life Cycle Assessment of Buildings with Brightway and Ecoinvent
#
# ## Computing Environmental Burdens
#
# First, we again load the necessary Brightway Python libraries.

# %%
import bw2data as bd
import bw2io as bi
import bw2calc as bc

# %% [markdown]
# ⚠️ Do we need to select an Ecoinvent project? Which one is available on the server?

# %%
bd.projects
# Out:
# Brightway2 projects manager with 8 objects:
# 	Another project
# 	USEEIO-1.1
# 	default
# 	ei_3_10
# 	ei_test_code
# 	fixture
# 	vehicle manufacting
# 	vehicle_manufacting
# Use `projects.report()` to get a report on all projects.

# %%
bd.projects.set_current('ei_3_10')

# %% [markdown]
# Now, we can check if the Ecoinvent database is available:

# %%
bd.databases
# Out:
# Databases dictionary with 3 object(s):
# 	Construction Database
# 	ecoinvent-3.10-biosphere
# 	ecoinvent-3.10-cutoff

# %% [markdown]
# We bind the Ecoinvent database to a variable `ei` for easier access:

# %%
ei = bd.Database("ecoinvent-3.10-cutoff")

# %% [markdown]
# We can define our _foreground database_, in an Excel file.
# The template file contains three simple processes:
#
# 1. `house construction`
# 2. `concrete operation`
# 3. `house demolition`
#
# These processes are linked to some processes from the Ecoinvent database.
# For example, the `house construction` process uses:
#
# 1. `market for concrete, 30MPa`
# 2.  `diesel, burned in building machine`
#
# 💻 You can search for Ecoinvent processes using [the EcoQuery search engine](https://ecoquery.ecoinvent.org/3.10/cutoff).
# 📖 The following commands are [explained in the _Learn Brightway_ online eBook](https://learn.brightway.dev/en/latest/content/chapters/BW25/BW25_introduction.html#importing-a-foreground-dataset-from-excel).

# %%
importer = bi.ExcelImporter("/Users/michaelweinold/Downloads/life_cycle_inventory.xlsx")
importer.apply_strategies()
importer.match_database(fields=["name", "unit", "reference product", "location"])
importer.match_database(
    "ecoinvent-3.10-cutoff", fields=["name", "unit", "location", "reference product"]
)
importer.match_database("ecoinvent-3.10-biosphere", fields=["name", "categories", "location"])
# Out:
# Extracted 3 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 0.09 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields

# %% [markdown]
# This should have added the three processes to a new Brightway database called `Construction Database`.
# It should include 3 individual processes (=graph nodes). Let's check that:

# %%
importer.statistics()
# Out:
# Graph statistics for `Construction Database` importer:
# 3 graph nodes:
# 	process: 3
# 5 graph edges:
# 	technosphere: 5
# 5 edges to the following databases:
# 	ecoinvent-3.10-cutoff: 5
# 0 unique unlinked edges (0 total):
# (3, 5, 0, 0)

# %% [markdown]
# If we made any mistakes in the naming of the processes, the associated reference product or units, we can check this by listing _unlinked exchanges_:

# %%
list(importer.unlinked)
# Out:
# []

# %% [markdown]
# If there are no unlinked exchanges, we can proceed to write the database to disk:

# %%
importer.write_database()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 5137.98it/s]
# 09:38:08+0200 [info     ] Vacuuming database
# Created database: Construction Database

# %% [markdown]
# Now, it will show up in the list of available databases: 🧞‍♂️

# %%
bd.databases
# Out:
# Databases dictionary with 3 object(s):
# 	Construction Database
# 	ecoinvent-3.10-biosphere
# 	ecoinvent-3.10-cutoff

# %% [markdown]
# 📖 You can look for Brightway commands in [the _Cheat Sheet_ section of the online documentation](https://docs.brightway.dev/en/latest/content/cheatsheet/index.html).
#
# We bind the construction to a variable `db_construction` for easier access:

# %%
db_construction = bd.Database("Construction Database")

# %% [markdown]
# To get a random process from the database, we can use:

# %%
act_random = db_construction.random()

# %% [markdown]
# To list all metadata of the process, we can use:

# %%
act_random.as_dict()
# Out:
# {'code': 'house_operation',
#  'location': 'AT',
#  'amount': 1,
#  'type': 'processwithreferenceproduct',
#  'unit': 'unit',
#  'reference product': 'annual house operation',
#  'name': 'house operation',
#  'worksheet name': 'house operation',
#  'database': 'Construction Database',
#  'id': 220447118013300737}

# %% [markdown]
# Now, we can compute the environmental burdens of the building operation.
# First, we select an impact assessment method. We can list them all with:

# %%
bd.methods
# Out:
# Methods dictionary with 668 objects, including:
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'acidification', 'acidification (incl. fate, average Europe total, A&B)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'climate change', 'global warming potential (GWP100)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'ecotoxicity: freshwater', 'freshwater aquatic ecotoxicity (FAETP inf)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'ecotoxicity: marine', 'marine aquatic ecotoxicity (MAETP inf)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'ecotoxicity: terrestrial', 'terrestrial ecotoxicity (TETP inf)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'energy resources: non-renewable', 'abiotic depletion potential (ADP): fossil fuels')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'eutrophication', 'eutrophication (fate not incl.)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'human toxicity', 'human toxicity (HTP inf)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'material resources: metals/minerals', 'abiotic depletion potential (ADP): elements (ultimate reserves)')
# 	('ecoinvent-3.10', 'CML v4.8 2016', 'ozone depletion', 'ozone layer depletion (ODP steady state)')
# Use `list(this object)` to get the complete list.

# %% [markdown]
# These are [Python tuples](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences). For now, we select the Global Warming Potential (GWP) method:

# %%
method_gwp = ('ecoinvent-3.10', 'CML v4.8 2016', 'climate change', 'global warming potential (GWP100)')

# %% [markdown]
# Second, we select the _functional unit_ of the assessment:

# %%
house_construction = bd.get_node(
    name="house construction",
    database="Construction Database"
)

# %% [markdown]
# Now, we can [set up the calculation](https://docs.brightway.dev/en/latest/content/cheatsheet/lca.html#single-functional-unit-and-lcia-set):

# %%
functional_unit, data_objs, _ = bd.prepare_lca_inputs(
    demand={house_construction: 1},
    method=method_gwp
)

# %% [markdown]
# ...and run it:

# %%
lca = bc.LCA(demand=functional_unit, data_objs=data_objs)
lca.lci()
lca.lcia()

# %% [markdown]
# This was your first real life cycle assessment calculation! We can view the results:

# %%
lca.score
# Out:
# 7291.5078429120495

# %% [markdown]
# We can also check the contributions of individual processes to the overall result:

# %%
lca.to_dataframe()
# Out:
#      row_index  col_index       amount              row_id  \
# 0          718      13679  4671.479965  202346863644446745
# 1          718       8478  1466.565763  202346863644446745
# 2          894      12758   200.135619  202346863673806851
# 3          718      19858    68.935284  202346863644446745
# 4          716       1419    59.433222  202346863644446742
# ..         ...        ...          ...                 ...
# 195        716      18290     0.572829  202346863644446742
# 196        716       8374     0.568163  202346863644446742
# 197         80      14787     0.562597  202346863556366395
# 198         80      12548     0.562597  202346863556366395
# 199        716      12525     0.555619  202346863644446742
#
#                  col_id              row_database  \
# 0    202347026903535616  ecoinvent-3.10-biosphere
# 1    202347001452498945  ecoinvent-3.10-biosphere
# 2    202347022201720834  ecoinvent-3.10-biosphere
# 3    202347059610718208  ecoinvent-3.10-biosphere
# 4    202346965503119360  ecoinvent-3.10-biosphere
# ..                  ...                       ...
# 195  202347051406659584  ecoinvent-3.10-biosphere
# 196  202347000936599552  ecoinvent-3.10-biosphere
# 197  202347032557457408  ecoinvent-3.10-biosphere
# 198  202347021081841664  ecoinvent-3.10-biosphere
# 199  202347020939235328  ecoinvent-3.10-biosphere
#
#                                  row_code                row_name  \
# 0    349b29d1-3e58-4c66-98b9-9d1a076efd2e  Carbon dioxide, fossil
# 1    349b29d1-3e58-4c66-98b9-9d1a076efd2e  Carbon dioxide, fossil
# 2    70ef743b-3ed5-4a6d-b192-fb6d62378555         Methane, fossil
# 3    349b29d1-3e58-4c66-98b9-9d1a076efd2e  Carbon dioxide, fossil
# 4    aa7cac3a-3625-41d4-bc54-33e2cf11ec46  Carbon dioxide, fossil
# ..                                    ...                     ...
# 195  aa7cac3a-3625-41d4-bc54-33e2cf11ec46  Carbon dioxide, fossil
# 196  aa7cac3a-3625-41d4-bc54-33e2cf11ec46  Carbon dioxide, fossil
# 197  f9749677-9c9f-4678-ab55-c607dfdc2cb9  Carbon dioxide, fossil
# 198  f9749677-9c9f-4678-ab55-c607dfdc2cb9  Carbon dioxide, fossil
# 199  aa7cac3a-3625-41d4-bc54-33e2cf11ec46  Carbon dioxide, fossil
#
#     row_location  row_unit  row_type                          row_categories  \
# 0           None  kilogram  emission                                     air
# 1           None  kilogram  emission                                     air
# 2           None  kilogram  emission  air::non-urban air or from high stacks
# 3           None  kilogram  emission                                     air
# 4           None  kilogram  emission  air::non-urban air or from high stacks
# ..           ...       ...       ...                                     ...
# 195         None  kilogram  emission  air::non-urban air or from high stacks
# 196         None  kilogram  emission  air::non-urban air or from high stacks
# 197         None  kilogram  emission          air::urban air close to ground
# 198         None  kilogram  emission          air::urban air close to ground
# 199         None  kilogram  emission  air::non-urban air or from high stacks
#
#     row_product           col_database                          col_code  \
# 0          None  ecoinvent-3.10-cutoff  e93cfaabe77e063ac14bfba7d3d4145f
# 1          None  ecoinvent-3.10-cutoff  b296455bcee6a84b80bca90ed02300da
# 2          None  ecoinvent-3.10-cutoff  78ec33cb6f6542829eb39977781e9e5d
# 3          None  ecoinvent-3.10-cutoff  4971ae3c9a017f22f018cd4ef9439186
# 4          None  ecoinvent-3.10-cutoff  54eebb408bca82913a19e19ecd8a3eb9
# ..          ...                    ...                               ...
# 195        None  ecoinvent-3.10-cutoff  5fecc6edf3f590f6efe0bb71bd0697f0
# 196        None  ecoinvent-3.10-cutoff  8440532fe33825e23d7e46e16724f217
# 197        None  ecoinvent-3.10-cutoff  cbee0a33e3ab4b3730ae3a8a3af0668c
# 198        None  ecoinvent-3.10-cutoff  514dd8cad521548d421bf33bcd8d91af
# 199        None  ecoinvent-3.10-cutoff  731ac5c1b98e2b513a2e80e6cefa9525
#
#                                               col_name col_location  \
# 0                                   clinker production           CH
# 1                   diesel, burned in building machine          GLO
# 2    natural gas venting from petroleum/natural gas...          GLO
# 3      diesel production, petroleum refinery operation          RoW
# 4                     sweet gas, burned in gas turbine          GLO
# ..                                                 ...          ...
# 195                    electricity production, lignite      US-SERC
# 196                  electricity production, hard coal        IN-GJ
# 197  treatment of waste mineral oil, hazardous wast...           CH
# 198  treatment of waste mineral oil, hazardous wast...           CH
# 199                  electricity production, hard coal        IN-AP
#
#           col_unit                     col_type  \
# 0         kilogram  processwithreferenceproduct
# 1        megajoule  processwithreferenceproduct
# 2      cubic meter  processwithreferenceproduct
# 3         kilogram  processwithreferenceproduct
# 4        megajoule  processwithreferenceproduct
# ..             ...                          ...
# 195  kilowatt hour  processwithreferenceproduct
# 196  kilowatt hour  processwithreferenceproduct
# 197       kilogram  processwithreferenceproduct
# 198       kilogram  processwithreferenceproduct
# 199  kilowatt hour  processwithreferenceproduct
#
#                   col_reference_product
# 0                               clinker
# 1    diesel, burned in building machine
# 2                   natural gas, vented
# 3                                diesel
# 4      sweet gas, burned in gas turbine
# ..                                  ...
# 195           electricity, high voltage
# 196           electricity, high voltage
# 197                   waste mineral oil
# 198                   waste mineral oil
# 199           electricity, high voltage
#
# [200 rows x 20 columns]

# %% [markdown]
# ## Basic Visualization of Results

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# We can now compare the impacts of the three life cycle stages:

# %%
functional_unit, data_objs, _ = bd.prepare_lca_inputs(
    demand={bd.get_node(name="house construction", database="Construction Database"): 1},
    method=method_gwp
)
lca = bc.LCA(demand=functional_unit, data_objs=data_objs)
lca.lci()
lca.lcia()
impact_construction = lca.score

# %%
functional_unit, data_objs, _ = bd.prepare_lca_inputs(
    demand={bd.get_node(name="house operation", database="Construction Database"): 1},
    method=method_gwp
)
lca = bc.LCA(demand=functional_unit, data_objs=data_objs)
lca.lci()
lca.lcia()
impact_operation = lca.score

# %%
functional_unit, data_objs, _ = bd.prepare_lca_inputs(
    demand={bd.get_node(name="house demolition", database="Construction Database"): 1},
    method=method_gwp
)
lca = bc.LCA(demand=functional_unit, data_objs=data_objs)
lca.lci()
lca.lcia()
impact_demolition = lca.score

# %%
categories = ['Construction', 'Operation', 'Demolition']
values = [impact_construction, impact_operation*50, impact_demolition]

plt.bar(categories, values)

plt.xlabel('Life Cycle Stage')
plt.ylabel('GWP(100) [kg CO2-eq]')
# Out:
# Text(0, 0.5, 'GWP(100) [kg CO2-eq]')
